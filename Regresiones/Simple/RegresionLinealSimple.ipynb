# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
dataset = pd.read_csv('lr_ds.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
plt.scatter(X_train, y_train, color = '#59C9A5')
plt.plot(X_train, regressor.predict(X_train), color = '#BE1E2D')
plt.title('Linear Regression(Conjunto de entrenamiento)')
plt.xlabel('X')
plt.ylabel('y')
plt.plot()
# Out:
# []

# %%
plt.scatter(X_test, y_test, color = '#F166AB')
plt.plot(X_train, regressor.predict(X_train), color = '#392E7B')
plt.title('Linear Regression(Conjunto de prueba)')
plt.xlabel('X')
plt.ylabel('y')
plt.plot()
# Out:
# []
