# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("polynomial-regression.csv")
x = data.araba_fiyat.values.reshape(-1,1)
y = data.araba_max_hiz.values.reshape(-1,1)

# %%
plt.scatter(x, y, color = '#59C9A5')
plt.plot(x, y, color = '#BE1E2D')
plt.title("Regresion Polinomica")
plt.plot()
# Out:
# []

# %%
#WHIT DEGREE 3
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

polynominal_regression = PolynomialFeatures(degree = 3)
x_polynomial = polynominal_regression.fit_transform(x,y)

# %% fit
linear_regression = LinearRegression()
linear_regression.fit(x_polynomial,y)
# %%
y_head2 = linear_regression.predict(x_polynomial)

plt.plot(x,y_head2,color= "green",label = "poly")
plt.legend()
plt.scatter(x,y)
plt.plot()

from sklearn.metrics import r2_score
print("Score: ", r2_score(y,y_head2))
# Out:
# Score:  0.944249822080344

# %%
#WHIT DEGREE 4
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

polynominal_regression = PolynomialFeatures(degree = 4)
x_polynomial = polynominal_regression.fit_transform(x,y)

# %% fit
linear_regression = LinearRegression()
linear_regression.fit(x_polynomial,y)
# %%
y_head2 = linear_regression.predict(x_polynomial)

plt.plot(x,y_head2,color= "green",label = "poly")
plt.legend()
plt.scatter(x,y)
plt.plot()

from sklearn.metrics import r2_score
print("Score: ", r2_score(y,y_head2))
# Out:
# Score:  0.9694743023211566

# %%
#WHIT DEGREE 5
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

polynominal_regression = PolynomialFeatures(degree = 5)
x_polynomial = polynominal_regression.fit_transform(x,y)

# %% fit
linear_regression = LinearRegression()
linear_regression.fit(x_polynomial,y)
# %%
y_head2 = linear_regression.predict(x_polynomial)

plt.plot(x,y_head2,color= "green",label = "poly")
plt.legend()
plt.scatter(x,y)
plt.plot()

from sklearn.metrics import r2_score
print("Score: ", r2_score(y,y_head2))
# Out:
# Score:  0.963129360646712
